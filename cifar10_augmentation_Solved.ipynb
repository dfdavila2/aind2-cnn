# %% [markdown]
# <a href="https://colab.research.google.com/github/dfdavila2/aind2-cnn/blob/master/cifar10_augmentation_Solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 32
epochs = 100

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=(x_valid, y_valid),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 37s - loss: 1.6810 - acc: 0.3865 - val_loss: 1.3481 - val_acc: 0.5062
#
# Epoch 00001: val_loss improved from inf to 1.34808, saving model to aug_model.weights.best.hdf5
# Epoch 2/100
#  - 30s - loss: 1.4020 - acc: 0.4909 - val_loss: 1.1530 - val_acc: 0.5902
#
# Epoch 00002: val_loss improved from 1.34808 to 1.15302, saving model to aug_model.weights.best.hdf5
# Epoch 3/100
#  - 30s - loss: 1.2962 - acc: 0.5350 - val_loss: 1.0946 - val_acc: 0.6144
#
# Epoch 00003: val_loss improved from 1.15302 to 1.09458, saving model to aug_model.weights.best.hdf5
# Epoch 4/100
#  - 30s - loss: 1.2293 - acc: 0.5615 - val_loss: 1.0948 - val_acc: 0.6178
#
# Epoch 00004: val_loss did not improve from 1.09458
# Epoch 5/100
#  - 30s - loss: 1.1988 - acc: 0.5749 - val_loss: 1.0284 - val_acc: 0.6488
#
# Epoch 00005: val_loss improved from 1.09458 to 1.02838, saving model to aug_model.weights.best.hdf5
# Epoch 6/100
#  - 30s - loss: 1.1796 - acc: 0.5857 - val_loss: 1.0802 - val_acc: 0.6188
#
# Epoch 00006: val_loss did not improve from 1.02838
# Epoch 7/100
#  - 30s - loss: 1.1692 - acc: 0.5942 - val_loss: 1.0440 - val_acc: 0.6450
#
# Epoch 00007: val_loss did not improve from 1.02838
# Epoch 8/100
#  - 30s - loss: 1.1756 - acc: 0.5922 - val_loss: 1.0209 - val_acc: 0.6382
#
# Epoch 00008: val_loss improved from 1.02838 to 1.02086, saving model to aug_model.weights.best.hdf5
# Epoch 9/100
#  - 30s - loss: 1.1610 - acc: 0.5982 - val_loss: 0.9668 - val_acc: 0.6710
#
# Epoch 00009: val_loss improved from 1.02086 to 0.96680, saving model to aug_model.weights.best.hdf5
# Epoch 10/100
#  - 30s - loss: 1.1664 - acc: 0.6030 - val_loss: 0.9827 - val_acc: 0.6686
#
# Epoch 00010: val_loss did not improve from 0.96680
# Epoch 11/100
#  - 30s - loss: 1.1801 - acc: 0.5947 - val_loss: 1.0814 - val_acc: 0.6356
#
# Epoch 00011: val_loss did not improve from 0.96680
# Epoch 12/100
#  - 30s - loss: 1.1752 - acc: 0.6001 - val_loss: 0.9772 - val_acc: 0.6608
#
# Epoch 00012: val_loss did not improve from 0.96680
# Epoch 13/100
#  - 30s - loss: 1.1984 - acc: 0.5909 - val_loss: 0.9783 - val_acc: 0.6640
#
# Epoch 00013: val_loss did not improve from 0.96680
# Epoch 14/100
#  - 30s - loss: 1.2061 - acc: 0.5891 - val_loss: 1.0187 - val_acc: 0.6570
#
# Epoch 00014: val_loss did not improve from 0.96680
# Epoch 15/100
#  - 30s - loss: 1.2338 - acc: 0.5843 - val_loss: 1.0790 - val_acc: 0.6342
#
# Epoch 00015: val_loss did not improve from 0.96680
# Epoch 16/100
#  - 30s - loss: 1.2449 - acc: 0.5792 - val_loss: 0.9899 - val_acc: 0.6698
#
# Epoch 00016: val_loss did not improve from 0.96680
# Epoch 17/100
#  - 30s - loss: 1.2610 - acc: 0.5718 - val_loss: 1.0584 - val_acc: 0.6410
#
# Epoch 00017: val_loss did not improve from 0.96680
# Epoch 18/100
#  - 30s - loss: 1.2821 - acc: 0.5671 - val_loss: 1.2389 - val_acc: 0.5936
#
# Epoch 00018: val_loss did not improve from 0.96680
# Epoch 19/100
#  - 30s - loss: 1.2932 - acc: 0.5638 - val_loss: 1.0032 - val_acc: 0.6560
#
# Epoch 00019: val_loss did not improve from 0.96680
# Epoch 20/100
#  - 30s - loss: 1.3019 - acc: 0.5596 - val_loss: 1.2141 - val_acc: 0.6188
#
# Epoch 00020: val_loss did not improve from 0.96680
# Epoch 21/100
#  - 30s - loss: 1.3173 - acc: 0.5564 - val_loss: 1.1112 - val_acc: 0.6414
#
# Epoch 00021: val_loss did not improve from 0.96680
# Epoch 22/100
#  - 30s - loss: 1.3415 - acc: 0.5471 - val_loss: 1.0561 - val_acc: 0.6512
#
# Epoch 00022: val_loss did not improve from 0.96680
# Epoch 23/100
#  - 30s - loss: 1.3499 - acc: 0.5454 - val_loss: 1.2542 - val_acc: 0.6020
#
# Epoch 00023: val_loss did not improve from 0.96680
# Epoch 24/100
#  - 30s - loss: 1.3674 - acc: 0.5405 - val_loss: 1.1764 - val_acc: 0.6202
#
# Epoch 00024: val_loss did not improve from 0.96680
# Epoch 25/100
#  - 30s - loss: 1.3939 - acc: 0.5318 - val_loss: 1.2110 - val_acc: 0.5930
#
# Epoch 00025: val_loss did not improve from 0.96680
# Epoch 26/100
#  - 30s - loss: 1.3951 - acc: 0.5286 - val_loss: 1.2077 - val_acc: 0.5852
#
# Epoch 00026: val_loss did not improve from 0.96680
# Epoch 27/100
#  - 30s - loss: 1.4069 - acc: 0.5283 - val_loss: 1.1730 - val_acc: 0.5812
#
# Epoch 00027: val_loss did not improve from 0.96680
# Epoch 28/100
#  - 30s - loss: 1.4274 - acc: 0.5210 - val_loss: 1.1754 - val_acc: 0.5954
#
# Epoch 00028: val_loss did not improve from 0.96680
# Epoch 29/100
#  - 30s - loss: 1.4329 - acc: 0.5166 - val_loss: 1.2123 - val_acc: 0.5960
#
# Epoch 00029: val_loss did not improve from 0.96680
# Epoch 30/100
#  - 30s - loss: 1.4424 - acc: 0.5168 - val_loss: 1.3303 - val_acc: 0.5286
#
# Epoch 00030: val_loss did not improve from 0.96680
# Epoch 31/100
#  - 30s - loss: 1.4502 - acc: 0.5108 - val_loss: 1.4115 - val_acc: 0.5316
#
# Epoch 00031: val_loss did not improve from 0.96680
# Epoch 32/100
#  - 30s - loss: 1.4556 - acc: 0.5077 - val_loss: 1.2136 - val_acc: 0.5802
#
# Epoch 00032: val_loss did not improve from 0.96680
# Epoch 33/100
#  - 30s - loss: 1.4743 - acc: 0.5004 - val_loss: 1.2821 - val_acc: 0.5760
#
# Epoch 00033: val_loss did not improve from 0.96680
# Epoch 34/100
#  - 30s - loss: 1.4917 - acc: 0.4977 - val_loss: 1.2737 - val_acc: 0.5936
#
# Epoch 00034: val_loss did not improve from 0.96680
# Epoch 35/100
#  - 30s - loss: 1.4919 - acc: 0.4948 - val_loss: 1.3046 - val_acc: 0.5488
#
# Epoch 00035: val_loss did not improve from 0.96680
# Epoch 36/100
#  - 30s - loss: 1.4992 - acc: 0.4948 - val_loss: 1.3799 - val_acc: 0.4982
#
# Epoch 00036: val_loss did not improve from 0.96680
# Epoch 37/100
#  - 30s - loss: 1.5076 - acc: 0.4924 - val_loss: 1.1949 - val_acc: 0.5830
#
# Epoch 00037: val_loss did not improve from 0.96680
# Epoch 38/100
#  - 30s - loss: 1.5119 - acc: 0.4846 - val_loss: 1.2802 - val_acc: 0.5422
#
# Epoch 00038: val_loss did not improve from 0.96680
# Epoch 39/100
#  - 30s - loss: 1.5156 - acc: 0.4848 - val_loss: 1.3109 - val_acc: 0.5480
#
# Epoch 00039: val_loss did not improve from 0.96680
# Epoch 40/100
#  - 30s - loss: 1.5193 - acc: 0.4835 - val_loss: 1.3879 - val_acc: 0.5296
#
# Epoch 00040: val_loss did not improve from 0.96680
# Epoch 41/100
#  - 30s - loss: 1.5345 - acc: 0.4806 - val_loss: 1.2412 - val_acc: 0.5734
#
# Epoch 00041: val_loss did not improve from 0.96680
# Epoch 42/100
#  - 30s - loss: 1.5458 - acc: 0.4766 - val_loss: 1.4977 - val_acc: 0.5410
#
# Epoch 00042: val_loss did not improve from 0.96680
# Epoch 43/100
#  - 30s - loss: 1.5543 - acc: 0.4723 - val_loss: 1.3395 - val_acc: 0.5474
#
# Epoch 00043: val_loss did not improve from 0.96680
# Epoch 44/100
#  - 30s - loss: 1.5787 - acc: 0.4618 - val_loss: 1.2313 - val_acc: 0.5862
#
# Epoch 00044: val_loss did not improve from 0.96680
# Epoch 45/100
#  - 30s - loss: 1.5814 - acc: 0.4617 - val_loss: 1.3010 - val_acc: 0.5678
#
# Epoch 00045: val_loss did not improve from 0.96680
# Epoch 46/100
#  - 30s - loss: 1.6004 - acc: 0.4529 - val_loss: 1.3960 - val_acc: 0.5252
#
# Epoch 00046: val_loss did not improve from 0.96680
# Epoch 47/100
#  - 30s - loss: 1.6183 - acc: 0.4487 - val_loss: 1.5090 - val_acc: 0.4816
#
# Epoch 00047: val_loss did not improve from 0.96680
# Epoch 48/100
#  - 30s - loss: 1.6401 - acc: 0.4378 - val_loss: 1.3839 - val_acc: 0.5134
#
# Epoch 00048: val_loss did not improve from 0.96680
# Epoch 49/100
#  - 30s - loss: 1.6519 - acc: 0.4368 - val_loss: 1.3973 - val_acc: 0.5048
#
# Epoch 00049: val_loss did not improve from 0.96680
# Epoch 50/100
#  - 30s - loss: 1.6640 - acc: 0.4296 - val_loss: 1.3710 - val_acc: 0.5248
#
# Epoch 00050: val_loss did not improve from 0.96680
# Epoch 51/100
#  - 30s - loss: 1.6538 - acc: 0.4300 - val_loss: 1.4635 - val_acc: 0.4916
#
# Epoch 00051: val_loss did not improve from 0.96680
# Epoch 52/100
#  - 30s - loss: 1.6871 - acc: 0.4180 - val_loss: 1.4691 - val_acc: 0.4988
#
# Epoch 00052: val_loss did not improve from 0.96680
# Epoch 53/100
#  - 30s - loss: 1.7022 - acc: 0.4113 - val_loss: 1.4162 - val_acc: 0.5094
#
# Epoch 00053: val_loss did not improve from 0.96680
# Epoch 54/100
#  - 30s - loss: 1.7113 - acc: 0.4115 - val_loss: 1.3958 - val_acc: 0.5196
#
# Epoch 00054: val_loss did not improve from 0.96680
# Epoch 55/100
#  - 30s - loss: 1.7217 - acc: 0.4056 - val_loss: 1.4150 - val_acc: 0.4786
#
# Epoch 00055: val_loss did not improve from 0.96680
# Epoch 56/100
#  - 30s - loss: 1.7246 - acc: 0.4062 - val_loss: 1.5663 - val_acc: 0.4238
#
# Epoch 00056: val_loss did not improve from 0.96680
# Epoch 57/100
#  - 30s - loss: 1.7229 - acc: 0.4043 - val_loss: 1.3403 - val_acc: 0.5342
#
# Epoch 00057: val_loss did not improve from 0.96680
# Epoch 58/100
#  - 30s - loss: 1.7556 - acc: 0.3982 - val_loss: 1.4887 - val_acc: 0.4634
#
# Epoch 00058: val_loss did not improve from 0.96680
# Epoch 59/100
#  - 30s - loss: 1.7406 - acc: 0.3913 - val_loss: 1.4341 - val_acc: 0.4852
#
# Epoch 00059: val_loss did not improve from 0.96680
# Epoch 60/100
#  - 30s - loss: 1.7577 - acc: 0.3879 - val_loss: 1.5440 - val_acc: 0.4490
#
# Epoch 00060: val_loss did not improve from 0.96680
# Epoch 61/100
#  - 30s - loss: 1.7718 - acc: 0.3839 - val_loss: 1.6136 - val_acc: 0.4302
#
# Epoch 00061: val_loss did not improve from 0.96680
# Epoch 62/100
#  - 30s - loss: 1.7661 - acc: 0.3801 - val_loss: 1.6071 - val_acc: 0.4396
#
# Epoch 00062: val_loss did not improve from 0.96680
# Epoch 63/100
#  - 30s - loss: 1.7822 - acc: 0.3757 - val_loss: 1.6405 - val_acc: 0.4488
#
# Epoch 00063: val_loss did not improve from 0.96680
# Epoch 64/100
#  - 30s - loss: 1.7942 - acc: 0.3694 - val_loss: 1.9274 - val_acc: 0.4022
#
# Epoch 00064: val_loss did not improve from 0.96680
# Epoch 65/100
#  - 30s - loss: 1.8049 - acc: 0.3666 - val_loss: 1.6664 - val_acc: 0.3950
#
# Epoch 00065: val_loss did not improve from 0.96680
# Epoch 66/100
#  - 30s - loss: 1.7919 - acc: 0.3737 - val_loss: 1.5252 - val_acc: 0.4546
#
# Epoch 00066: val_loss did not improve from 0.96680
# Epoch 67/100
#  - 30s - loss: 1.8059 - acc: 0.3680 - val_loss: 1.8051 - val_acc: 0.3990
#
# Epoch 00067: val_loss did not improve from 0.96680
# Epoch 68/100
#  - 30s - loss: 1.7965 - acc: 0.3707 - val_loss: 1.5616 - val_acc: 0.4544
#
# Epoch 00068: val_loss did not improve from 0.96680
# Epoch 69/100
#  - 30s - loss: 1.7985 - acc: 0.3668 - val_loss: 1.7236 - val_acc: 0.3718
#
# Epoch 00069: val_loss did not improve from 0.96680
# Epoch 70/100
#  - 30s - loss: 1.8041 - acc: 0.3663 - val_loss: 1.5998 - val_acc: 0.4460
#
# Epoch 00070: val_loss did not improve from 0.96680
# Epoch 71/100
#  - 30s - loss: 1.8076 - acc: 0.3636 - val_loss: 1.6234 - val_acc: 0.4158
#
# Epoch 00071: val_loss did not improve from 0.96680
# Epoch 72/100
#  - 30s - loss: 1.8170 - acc: 0.3586 - val_loss: 1.6190 - val_acc: 0.4206
#
# Epoch 00072: val_loss did not improve from 0.96680
# Epoch 73/100
#  - 30s - loss: 1.8346 - acc: 0.3488 - val_loss: 1.6709 - val_acc: 0.4378
#
# Epoch 00073: val_loss did not improve from 0.96680
# Epoch 74/100
#  - 30s - loss: 1.8385 - acc: 0.3509 - val_loss: 1.5778 - val_acc: 0.4510
#
# Epoch 00074: val_loss did not improve from 0.96680
# Epoch 75/100
#  - 30s - loss: 1.8342 - acc: 0.3485 - val_loss: 1.6192 - val_acc: 0.4390
#
# Epoch 00075: val_loss did not improve from 0.96680
# Epoch 76/100
#  - 30s - loss: 1.8306 - acc: 0.3465 - val_loss: 1.7094 - val_acc: 0.3768
#
# Epoch 00076: val_loss did not improve from 0.96680
# Epoch 77/100
#  - 30s - loss: 1.8626 - acc: 0.3415 - val_loss: 1.5898 - val_acc: 0.4406
#
# Epoch 00077: val_loss did not improve from 0.96680
# Epoch 78/100
#  - 30s - loss: 1.8429 - acc: 0.3440 - val_loss: 1.7001 - val_acc: 0.4362
#
# Epoch 00078: val_loss did not improve from 0.96680
# Epoch 79/100
#  - 30s - loss: 1.8548 - acc: 0.3462 - val_loss: 1.5588 - val_acc: 0.4620
#
# Epoch 00079: val_loss did not improve from 0.96680
# Epoch 80/100
#  - 30s - loss: 1.8563 - acc: 0.3360 - val_loss: 1.5838 - val_acc: 0.4458
#
# Epoch 00080: val_loss did not improve from 0.96680
# Epoch 81/100
#  - 30s - loss: 1.8673 - acc: 0.3362 - val_loss: 1.6759 - val_acc: 0.4158
#
# Epoch 00081: val_loss did not improve from 0.96680
# Epoch 82/100
#  - 30s - loss: 1.8667 - acc: 0.3338 - val_loss: 1.6331 - val_acc: 0.4276
#
# Epoch 00082: val_loss did not improve from 0.96680
# Epoch 83/100
#  - 30s - loss: 1.8690 - acc: 0.3314 - val_loss: 1.7691 - val_acc: 0.3690
#
# Epoch 00083: val_loss did not improve from 0.96680
# Epoch 84/100
#  - 30s - loss: 1.8947 - acc: 0.3219 - val_loss: 1.6758 - val_acc: 0.3760
#
# Epoch 00084: val_loss did not improve from 0.96680
# Epoch 85/100
#  - 30s - loss: 1.9046 - acc: 0.3210 - val_loss: 1.7412 - val_acc: 0.3780
#
# Epoch 00085: val_loss did not improve from 0.96680
# Epoch 86/100
#  - 30s - loss: 1.9051 - acc: 0.3169 - val_loss: 1.7014 - val_acc: 0.3566
#
# Epoch 00086: val_loss did not improve from 0.96680
# Epoch 87/100
#  - 30s - loss: 1.9003 - acc: 0.3137 - val_loss: 1.6446 - val_acc: 0.3978
#
# Epoch 00087: val_loss did not improve from 0.96680
# Epoch 88/100
#  - 30s - loss: 1.9371 - acc: 0.3059 - val_loss: 1.7301 - val_acc: 0.3732
#
# Epoch 00088: val_loss did not improve from 0.96680
# Epoch 89/100
#  - 30s - loss: 1.9483 - acc: 0.2940 - val_loss: 1.7359 - val_acc: 0.3794
#
# Epoch 00089: val_loss did not improve from 0.96680
# Epoch 90/100
#  - 30s - loss: 1.9596 - acc: 0.2941 - val_loss: 1.6807 - val_acc: 0.3922
#
# Epoch 00090: val_loss did not improve from 0.96680
# Epoch 91/100
#  - 30s - loss: 1.9596 - acc: 0.2885 - val_loss: 1.7520 - val_acc: 0.3674
#
# Epoch 00091: val_loss did not improve from 0.96680
# Epoch 92/100
#  - 30s - loss: 1.9630 - acc: 0.2850 - val_loss: 1.7853 - val_acc: 0.3376
#
# Epoch 00092: val_loss did not improve from 0.96680
# Epoch 93/100
#  - 30s - loss: 1.9656 - acc: 0.2825 - val_loss: 1.7994 - val_acc: 0.3440
#
# Epoch 00093: val_loss did not improve from 0.96680
# Epoch 94/100
#  - 30s - loss: 1.9681 - acc: 0.2773 - val_loss: 1.8585 - val_acc: 0.3148
#
# Epoch 00094: val_loss did not improve from 0.96680
# Epoch 95/100
#  - 30s - loss: 1.9686 - acc: 0.2728 - val_loss: 1.8598 - val_acc: 0.3284
#
# Epoch 00095: val_loss did not improve from 0.96680
# Epoch 96/100
#  - 30s - loss: 1.9647 - acc: 0.2724 - val_loss: 1.7782 - val_acc: 0.3482
#
# Epoch 00096: val_loss did not improve from 0.96680
# Epoch 97/100
#  - 30s - loss: 1.9643 - acc: 0.2768 - val_loss: 1.8027 - val_acc: 0.3204
#
# Epoch 00097: val_loss did not improve from 0.96680
# Epoch 98/100
#  - 30s - loss: 1.9498 - acc: 0.2770 - val_loss: 1.8169 - val_acc: 0.3330
#
# Epoch 00098: val_loss did not improve from 0.96680
# Epoch 99/100
#  - 30s - loss: 1.9476 - acc: 0.2776 - val_loss: 1.8083 - val_acc: 0.3242
#
# Epoch 00099: val_loss did not improve from 0.96680
# Epoch 100/100
#  - 30s - loss: 1.9458 - acc: 0.2787 - val_loss: 1.8631 - val_acc: 0.3228
#
# Epoch 00100: val_loss did not improve from 0.96680

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6499
